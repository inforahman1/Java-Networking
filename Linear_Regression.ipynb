# %% [markdown]
# <a href="https://colab.research.google.com/github/inforahman1/Java-Networking/blob/master/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
size = np.array([1400, 1600, 1700, 1875, 1100, 1550, 2350, 2450, 1425, 1700])
price = np.array([245000, 312000, 279000, 308000, 199000, 219000, 405000, 324000, 319000, 255000])

# %%
plt.title('size & Price')
plt.xlabel('size (squar feet)')
plt.ylabel('price (monthly)')
plt.show()

# %%
size = size.reshape(-1, 1)

# %%
size_train, size_test, price_train, price_test= train_test_split(size, price, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(size_train, price_train)
# Out:
# LinearRegression()

# %%
mse = mean_squared_error(price_test, [219000, 245000])
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 7244500000.0

# %%
plt.scatter(size_test, price_test)
plt.plot(size_test, price_pred, color='red', linewidth = 2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-44ca5c597990> in <cell line: 2>()
#       1 plt.scatter(size_test, price_test)
# ----> 2 plt.plot(size_test, price_pred, color='red', linewidth = 2)
#
# NameError: name 'price_pred' is not defined

# %%
plt.title('1525')
plt.xlabel('size (sft)')
plt.ylabel('price(monthly)')
plt.show()
