# %% [markdown]
# <a href="https://colab.research.google.com/github/inforahman1/Java-Networking/blob/master/survey_2023_211010241.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer

# %%
df = pd.read_csv("Survey_2023 - Sheet1.csv")

# %%
df.head()
# Out:
#              Timestamp   Student Name Gender Month of birth Birthyear  \
# 0  11/11/2023 14:29:52    james smith   Male       December      2002
# 1  11/11/2023 14:33:24  michael smith   Male       December      1999
# 2  11/11/2023 14:33:52   robert smith   Male      September      2000
# 3  11/11/2023 14:34:11    david smith   Male          March      1998
# 4  11/11/2023 18:11:41  james johnson   Male          April      1989
#
#   OS of Mobile Mobile Brand   Sim Company SSC Board  SSC year  ...  \
# 0      Andorid        Tecno          Robi     Dhaka    2017.0  ...
# 1      Andorid       Realme          Robi   Cumilla    2015.0  ...
# 2      Andorid      Samsung        Airtel     Dhaka    2017.0  ...
# 3       iPhone       Iphone  Grameenphone     Dhaka    2014.0  ...
# 4      Andorid      Infinix      Teletalk  Rajshahi    2004.0  ...
#
#   Average sleeping hour Second Language Religion Marriage status  \
# 0                   6.0         English   Muslim              No
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 39 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Timestamp                      60 non-null     object
#  1   Student Name                   60 non-null     object
#  2   Gender                         60 non-null     object
#  3   Month of birth                 60 non-null     object
#  4   Birthyear                      59 non-null     object
#  5   OS of Mobile                   59 non-null     object
#  6   Mobile Brand                   57 non-null     object
#  7   Sim Company                    60 non-null     object
#  8   SSC Board                      60 non-null     object
#  9   SSC year                       60 non-null     float64
#  10  SSC Grade                      60 non-null     object
#  11  HSC Board                      57 non-null     object
# ...

# %%
df.describe()
# Out:
#           SSC year  Average sleeping hour   2*2  University experience  \
# count    60.000000              59.000000  59.0              59.000000
# mean   2017.950000               6.694915   4.0               3.779661
# std       2.280537               1.102571   0.0               1.018244
# min    2004.000000               4.000000   4.0               1.000000
# 25%    2017.000000               6.000000   4.0               3.000000
# 50%    2018.000000               7.000000   4.0               4.000000
# 75%    2019.000000               8.000000   4.0               5.000000
# max    2020.000000               9.000000   4.0               5.000000
#
#            Batch
# count  60.000000
# mean   11.950000
# std     2.094585
# min     9.000000
# 25%    10.000000
# 50%    12.500000
# 75%    14.000000
# max    14.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
from matplotlib import pyplot as plt
_df_0['SSC year'].plot(kind='hist', bins=20, title='SSC year')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_1['Average sleeping hour'].plot(kind='hist', bins=20, title='Average sleeping hour')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_2['2*2'].plot(kind='hist', bins=20, title='2*2')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_3['University experience'].plot(kind='hist', bins=20, title='University experience')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_4.plot(kind='scatter', x='SSC year', y='Average sleeping hour', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_5.plot(kind='scatter', x='Average sleeping hour', y='2*2', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_6.plot(kind='scatter', x='2*2', y='University experience', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_7.plot(kind='scatter', x='University experience', y='Batch', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_8['SSC year'].plot(kind='line', figsize=(8, 4), title='SSC year')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_9['Average sleeping hour'].plot(kind='line', figsize=(8, 4), title='Average sleeping hour')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_10['2*2'].plot(kind='line', figsize=(8, 4), title='2*2')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_11['University experience'].plot(kind='line', figsize=(8, 4), title='University experience')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
plt.title('Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Scatter Plot')
